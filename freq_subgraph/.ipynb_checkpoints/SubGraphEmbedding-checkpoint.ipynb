# %%
import pandas as pd
from sklearn.neighbors import BallTree
import networkx as nx
import umap
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from hopkins import hopkins

from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

from sklearn.model_selection import RandomizedSearchCV
from sklearn.base import BaseEstimator, ClusterMixin
from sklearn.cluster import DBSCAN, HDBSCAN
import matplotlib.pyplot as plt

import copy
from SF import SF

import os
os.environ["NUMBA_NUM_THREADS"] = "8"

import math

# %%
RANDOM_SEED = False
if RANDOM_SEED:
    np.random.seed(None)
    st0 = np.random.get_state()
    np.save('random.npy', np.array(st0, dtype=object), allow_pickle=True)
else:
    st0 = np.load('random.npy', allow_pickle=True).tolist()
    np.random.set_state(st0)

# %%
frequent_subgraph = []
node_labels = []
edge_labels = []
suports = []
edge_weights = []
G = None
with open("out.txt") as file:
    for line in file:
        if (line.startswith("t")):
            if not(G is None):
                frequent_subgraph.append(G)
                node_labels.append(node_label)
                edge_labels.append(edge_label)
                edge_weights.append(edge_weight)
                suports.append(suport)
                nx.set_node_attributes(G, node_label, name="label")
                nx.set_edge_attributes(G, edge_label, name='label')
                nx.set_edge_attributes(G, edge_weight, name='crisp')
                nx.set_node_attributes(G, node_latex, name='latex')
            G = nx.Graph()
            node_label = {}
            edge_label = {}
            node_latex = {}
            edge_weight = {}
            suport = []
        if (line.startswith("v")):
            values = line.split(' ')
            G.add_node(int(values[1]))
            node_label[int(values[1])] = chr( 64 + int(values[2]))
            node_latex[int(values[1])] = '[fill=red!20,draw,double,rounded corners]'
        if (line.startswith("e")):
            values = line.split(' ')
            G.add_edge(int(values[1]), int(values[2]), weight=1)
            edge_weight[(int(values[1]), int(values[2]))] = int(values[3]) + 1
            if (values[3].strip() == '0'):
                edge_label[(int(values[1]), int(values[2]))] = 'Low'
            elif (values[3].strip() == '1'):
                edge_label[(int(values[1]), int(values[2]))] = 'Medium'
            else:
                edge_label[(int(values[1]), int(values[2]))] = 'High'
        if (line.startswith("x")):
            suport = [int(ele) for ele in line.replace("x ", "").split()]

# %%
from collections import Counter

words = list(nx.get_edge_attributes(frequent_subgraph[5], 'label').values())

Counter(words)
# Out:
# Counter({'Low': 1})

# %%
total_vertex = 0
rank = []
for g in frequent_subgraph:
    total_vertex = total_vertex + len(g.nodes())
alpha = float(len(frequent_subgraph)) / float( total_vertex)
for g in frequent_subgraph:
    d = sum([val for (_, val) in g.degree()])
    n = len(g.nodes())
    edges_labels = Counter(list(nx.get_edge_attributes(g, 'label').values()))
    w = (edges_labels['Low'] * 1 if 'Low' in edges_labels else 0) + (edges_labels['Medium'] * 5 if 'Medium' in edges_labels else 0) + (edges_labels['High'] * 15 if 'High' in edges_labels else 0 )
    w = w / (1+5+15)
    rank.append( (1-alpha) * (w + (alpha * (d/n)) ))

# %%
def plot_graph(index, graphs=frequent_subgraph, node_labels=node_labels, edge_labels=edge_labels, suports=suports):
    plt.figure()  
    plt.title("Suport: {:.0%} Rank: {:.0%} L2 {:.2f}".format(len(suports[index])/47.0, rank[index], math.sqrt( (rank[index]**2) + ((len(suports[index])/47.0)**2) )) )
    pos = nx.planar_layout(frequent_subgraph[index])
    nx.draw(frequent_subgraph[index], pos, labels=node_labels[index], node_shape="s",bbox=dict(facecolor="orange", edgecolor='black', boxstyle='round,pad=0.2'))
    nx.draw_networkx_edge_labels(frequent_subgraph[index], pos, edge_labels=edge_labels[index], font_color='green', verticalalignment='top')
    print(nx.to_latex_raw(frequent_subgraph[index], pos, node_label=node_labels[index], tikz_options="[scale=2.5]", edge_label=edge_labels[index], edge_label_options='above', default_edge_options='above', node_options='latex'))
    plt.show()

# %%
l2 = [ math.sqrt( ((rank[i])**2) + (len(suports[i])/47.0)**2 ) for i in range(len(suports))]

# %%
plt.scatter(rank, [len(i)/47.0 for i in suports])

# %%
for i in np.where(np.asarray(l2) >= 2.051155568802643)[0]:
    plot_graph(i)
# Out:
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-0.778, -0.333) node[fill=red!20,draw,double,rounded corners] (0){C}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){G}
#         (-0.333, 0.111) node[fill=red!20,draw,double,rounded corners] (2){H}
#         (0.111, 0.556) node[fill=red!20,draw,double,rounded corners] (3){M};
#       \begin{scope}[-,above]
#         \draw (0) to node[] {High} (1);
#         \draw[loop,] (1) to node[] {High} (1);
#         \draw (1) to node[] {Medium} (2);
#         \draw (1) to node[] {Medium} (3);
#         \draw[loop,] (2) to node[] {Medium} (2);
#       \end{scope}
#     \end{tikzpicture}
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-0.667, -0.333) node[fill=red!20,draw,double,rounded corners] (0){C}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){G}
#         (-0.389, -0.056) node[fill=red!20,draw,double,rounded corners] (2){H}
# ...

# %%
plt.scatter(rank, [len(s)/47.0 for s in suports])

# %%
plot_graph(969)
# Out:
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (0){C}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){G}
#         (0.0, 0.667) node[fill=red!20,draw,double,rounded corners] (2){M};
#       \begin{scope}[-,above]
#         \draw (0) to node[] {High} (1);
#         \draw[loop,] (1) to node[] {High} (1);
#         \draw (1) to node[] {Medium} (2);
#       \end{scope}
#     \end{tikzpicture}

# %%
for i  in np.where(np.asarray(rank) == max(rank))[0]:
    plot_graph(i)
# Out:
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (0){C}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){G}
#         (0.0, 0.667) node[fill=red!20,draw,double,rounded corners] (2){S};
#       \begin{scope}[-,above]
#         \draw (0) to node[] {High} (1);
#         \draw (0) to node[] {Low} (2);
#         \draw[loop,] (1) to node[] {High} (1);
#         \draw[loop,] (2) to node[] {Low} (2);
#       \end{scope}
#     \end{tikzpicture}
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (0){C}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){G}
#         (0.0, 0.667) node[fill=red!20,draw,double,rounded corners] (2){H};
#       \begin{scope}[-,above]
#         \draw (0) to node[] {High} (1);
#         \draw[loop,] (1) to node[] {High} (1);
#         \draw (1) to node[] {Medium} (2);
# ...

# %%
def hopkins_x(data_frame, sampling_size):
    """Assess the clusterability of a dataset. A score between 0 and 1, a score around 0.5 express
    no clusterability and a score tending to 0 express a high cluster tendency.

    Parameters
    ----------
    data_frame : numpy array
        The input dataset
    sampling_size : int
        The sampling size which is used to evaluate the number of DataFrame.

    Returns
    ---------------------
    score : float
        The hopkins score of the dataset (between 0 and 1)

    Examples
    --------
    >>> from sklearn import datasets
    >>> from pyclustertend import hopkins
    >>> X = datasets.load_iris().data
    >>> hopkins(X,150)
    0.16
    """

    if type(data_frame) == np.ndarray:
        data_frame = pd.DataFrame(data_frame)

    # Sample n observations from D : P

    if sampling_size > data_frame.shape[0]:
        raise Exception(
            'The number of sample of sample is bigger than the shape of D')

    data_frame_sample = data_frame.sample(n=sampling_size)

    # Get the distance to their neirest neighbors in D : X

    tree = BallTree(data_frame, leaf_size=2)
    dist, _ = tree.query(data_frame_sample, k=2)
    data_frame_sample_distances_to_nearest_neighbours = dist[:, 1]

    # Randomly simulate n points with the same variation as in D : Q.

    max_data_frame = data_frame.max()
    min_data_frame = data_frame.min()

    uniformly_selected_values_0 = np.random.uniform(min_data_frame[0], max_data_frame[0], sampling_size)
    uniformly_selected_values_1 = np.random.uniform(min_data_frame[1], max_data_frame[1], sampling_size)

    uniformly_selected_observations = np.column_stack((uniformly_selected_values_0, uniformly_selected_values_1))
    if len(max_data_frame) >= 2:
        for i in range(2, len(max_data_frame)):
            uniformly_selected_values_i = np.random.uniform(min_data_frame[i], max_data_frame[i], sampling_size)
            to_stack = (uniformly_selected_observations, uniformly_selected_values_i)
            uniformly_selected_observations = np.column_stack(to_stack)

    uniformly_selected_observations_df = pd.DataFrame(uniformly_selected_observations)

    # Get the distance to their neirest neighbors in D : Y

    tree = BallTree(data_frame, leaf_size=2)
    dist, _ = tree.query(uniformly_selected_observations_df, k=1)
    uniformly_df_distances_to_nearest_neighbours = dist

    # return the hopkins score

    x = sum(data_frame_sample_distances_to_nearest_neighbours)
    y = sum(uniformly_df_distances_to_nearest_neighbours)

    if x + y == 0:
        raise Exception('The denominator of the hopkins statistics is null')

    return x / (x + y)[0]

# %%
# function to compute hopkins's statistic for the dataframe X
from numpy.random import uniform
from random import sample
from sklearn.neighbors import NearestNeighbors
def hopkins_statistic(X):
    
    X=X #.values  #convert dataframe to a numpy array
    sample_size = int(X.shape[0]*0.05) #0.05 (5%) based on paper by Lawson and Jures
    
    
    #a uniform random sample in the original data space
    X_uniform_random_sample = uniform(X.min(axis=0), X.max(axis=0) ,(sample_size , X.shape[1]))
    
    
    
    #a random sample of size sample_size from the original data X
    random_indices=sample(range(0, X.shape[0], 1), sample_size)
    X_sample = X[random_indices]
   
    
    #initialise unsupervised learner for implementing neighbor searches
    neigh = NearestNeighbors(n_neighbors=2)
    nbrs=neigh.fit(X)
    
    #u_distances = nearest neighbour distances from uniform random sample
    u_distances , u_indices = nbrs.kneighbors(X_uniform_random_sample , n_neighbors=2)
    u_distances = u_distances[: , 0] #distance to the first (nearest) neighbour
    
    #w_distances = nearest neighbour distances from a sample of points from original data X
    w_distances , w_indices = nbrs.kneighbors(X_sample , n_neighbors=2)
    #distance to the second nearest neighbour (as the first neighbour will be the point itself, with distance = 0)
    w_distances = w_distances[: , 1]
    
 
    
    u_sum = np.sum(u_distances)
    w_sum = np.sum(w_distances)
    
    #compute and return hopkins' statistic
    H = u_sum/ (u_sum + w_sum)
    return H

# %%
import warnings
warnings.filterwarnings("ignore")
from tqdm.notebook import trange, tqdm
TRAIN = False
n_neighbors = 200
min_dist = 0.5
n_components = 2
metric = 'euclidean'
embedding_d = 128
s = int(0.05*1180)
hopkins = np.float64(0.0013722214672422046)
if TRAIN:
    for sf_d in tqdm((16, 32, 64 , 128)):
        model = SF(sf_d, 42)
        model.fit(copy.deepcopy(frequent_subgraph) )
        x = StandardScaler().fit_transform(model.get_embedding())
        metrics = []
        for n in tqdm((2, 5, 10, 20, 50, 100, 200), leave=False):
            for d in tqdm((0.0, 0.1, 0.25, 0.5, 0.8, 0.99), leave=False):
                for c in tqdm((2, 3), leave=False):
                    for m in tqdm(('euclidean','manhattan','chebyshev','minkowski'), leave=False):
                        reducer = umap.UMAP(n_neighbors=n, min_dist=d, n_components=c, metric=m)
                        embedding = reducer.fit_transform(x)
                        hopkins = np.mean([hopkins_x(embedding, s) for _ in range(20)]).item()
                        metrics.append({'embedding_d': sf_d, 'n_neighbors':n, 'min_dist':d, 'n_components':c, 'metric':m, 'statistic': hopkins})
    best = metrics[np.where( [i['statistic'] for i in metrics ] == np.min( [i['statistic'] for i in metrics ]))[0][0]]
    n_neighbors = best['n_neighbors']
    min_dist = best['min_dist']
    n_components = best['n_components']
    metric = best['metric']
    embedding_d = best['embedding_d']

model = SF(embedding_d, 42)
model.fit(copy.deepcopy(frequent_subgraph) )
x = StandardScaler().fit_transform(model.get_embedding())
reducer = umap.UMAP(n_neighbors=n_neighbors, min_dist=min_dist, n_components=n_components, metric=metric,random_state=10)
embedding = reducer.fit_transform(x)

# %%
x=[hopkins_statistic(embedding).item() for _ in range(100)]

# %%
embedding
# Out:
# array([[11.584717, 15.160549],
#        [21.249084, 20.21999 ],
#        [20.55908 , 19.502296],
#        ...,
#        [22.12441 , 19.675966],
#        [20.240623, 19.113089],
#        [20.049564, 19.44742 ]], dtype=float32)

# %%
(np.mean(x),np.std(x))
# Out:
# (np.float64(0.9971980032744132), np.float64(0.0003308611878172459))

# %%
import matplotlib.pyplot as plt
plt.scatter(
    embedding[:, 0],
    embedding[:, 1])

# %%
def plot(X, labels, probabilities=None, parameters=None, ground_truth=False, ax=None):
    if ax is None:
        _, ax = plt.subplots(figsize=(10, 4))
    labels = labels if labels is not None else np.ones(X.shape[0])
    probabilities = probabilities if probabilities is not None else np.ones(X.shape[0])
    # Black removed and is used for noise instead.
    unique_labels = set(labels)
    colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
    # The probability of a point belonging to its labeled cluster determines
    # the size of its marker
    proba_map = {idx: probabilities[idx] for idx in range(len(labels))}
    for k, col in zip(unique_labels, colors):
        if k == -1:
            # Black used for noise.
            col = [0, 0, 0, 1]

        class_index = np.where(labels == k)[0]
        for ci in class_index:
            ax.plot(
                X[ci, 0],
                X[ci, 1],
                "x" if k == -1 else "o",
                markerfacecolor=tuple(col),
                markeredgecolor="k",
                markersize=4 if k == -1 else 1 + 5 * proba_map[ci],
            )
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    preamble = "True" if ground_truth else "Estimated"
    title = f"{preamble} number of clusters: {n_clusters_}"
    if parameters is not None:
        parameters_str = ", ".join(f"{k}={v}" for k, v in parameters.items())
        title += f" | {parameters_str}"
    ax.set_title(title)
    plt.tight_layout()

# %%
# Criar uma classe adaptadora para integrar o HDBSCAN com scikit-learn
class HDBSCANWrapper(BaseEstimator, ClusterMixin):
    def __init__(self, min_cluster_size=5, min_samples=None, cluster_selection_epsilon=0.0):
        self.min_cluster_size = min_cluster_size
        self.min_samples = min_samples
        self.cluster_selection_epsilon = cluster_selection_epsilon

    def fit(self, X, y=None):
        self.clusterer_ = HDBSCAN(
            min_cluster_size=self.min_cluster_size,
            min_samples=self.min_samples,
            cluster_selection_epsilon=self.cluster_selection_epsilon
        )
        self.labels_ = self.clusterer_.fit_predict(X)
        return self

    def fit_predict(self, X, y=None):
        self.fit(X)
        return self.labels_

# Configurar os espaços de hiperparâmetros para busca
param_dist = {
    'min_cluster_size': np.arange(5, 20, 5),
    'min_samples': [5, 10, None],
    'cluster_selection_epsilon': np.linspace(0.0, 0.3, 4)
}

# Criar o wrapper para HDBSCAN
model = HDBSCANWrapper()

# Definir a métrica de avaliação como Silhouette Score
def silhouette_scorer(estimator, X):
    labels = estimator.fit_predict(X)
    if len(set(labels)) <= 1:  # Ignorar configurações com 1 ou nenhum cluster
        return -1
    return silhouette_score(X, labels)

# Configurar a busca de hiperparâmetros com RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_dist,
    scoring=silhouette_scorer,
    n_iter=20,  # Número de combinações aleatórias a testar
    cv=None,  # Não usamos validação cruzada para clustering
    verbose=1,
    random_state=42
)

# Realizar a busca
random_search.fit(StandardScaler().fit_transform(embedding))

# Resultados
print("Melhores parâmetros:", random_search.best_params_)
print("Melhor Silhouette Score:", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Melhores parâmetros: {'min_samples': 5, 'min_cluster_size': np.int64(5), 'cluster_selection_epsilon': np.float64(0.09999999999999999)}
# Melhor Silhouette Score: 0.9453336715698242

# %%
random_search.best_params_
# Out:
# {'min_samples': 5,
#  'min_cluster_size': np.int64(5),
#  'cluster_selection_epsilon': np.float64(0.09999999999999999)}

# %%
hdb = HDBSCAN(**random_search.best_params_).fit(StandardScaler().fit_transform(embedding))
labels = hdb.labels_
print(set(hdb.labels_.tolist()))
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
# Função para calcular as métricas de clustering

def calculate_cluster_metrics(X, labels):
    # Remover pontos classificados como ruído (-1) para evitar erros nas métricas
    mask = np.where(labels != -1)
    if len(set(labels[mask])) < 2:  # Verificar se há pelo menos dois clusters válidos
        return {
            "Silhouette Score": "Não aplicável",
            "Calinski-Harabasz Score": "Não aplicável",
            "Davies-Bouldin Score": "Não aplicável",
            "Número de clusters": len(set(labels[mask])),
            "Pontos como ruído": np.sum(labels == -1)
        }
    
    metrics = {
        "Silhouette Score": silhouette_score(X[mask], labels[mask]),
        "Calinski-Harabasz Score": calinski_harabasz_score(X[mask], labels[mask]),
        "Davies-Bouldin Score": davies_bouldin_score(X[mask], labels[mask]),
        "Número de clusters": len(set(labels[mask])),
        "Pontos como ruído": np.sum(labels == -1)
    }
    return metrics
calculate_cluster_metrics(StandardScaler().fit_transform(embedding), hdb.labels_)
# Out:
# {'Silhouette Score': np.float32(0.9391252),
#  'Calinski-Harabasz Score': np.float32(586177.94),
#  'Davies-Bouldin Score': np.float64(0.0708282963152342),
#  'Número de clusters': 7,
#  'Pontos como ruído': np.int64(0)}

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 5))
plot(StandardScaler().fit_transform(embedding), hdb.labels_, hdb.probabilities_,  ax=axes)
fig.savefig('cluster.png')   # save the figure to file
plt.close(fig)    # close the figure window

# %%
unique, counts_cls_total = np.unique(hdb.labels_, return_counts=True)
dict(zip(unique.tolist(), counts_cls_total.tolist()))
# Out:
# {0: 22, 1: 320, 2: 38, 3: 323, 4: 128, 5: 88, 6: 261}

# %%
import math
metrics = {}
for grupo in set(hdb.labels_.tolist()):
    metric = {}
    assortive = []
    nodes = []
    density = []
    diamenter = []
    max_degree = []
    labels = []
    support=[]
    for i in np.where(hdb.labels_ == grupo)[0].tolist():
        z = nx.degree_pearson_correlation_coefficient(frequent_subgraph[i],weight='crisp')
        if math.isnan(z):
            print(i)
            z = 1
        assortive.append(z)
        max_degree.append(max([val for (_, val) in frequent_subgraph[i].degree()]))
        nodes.append(frequent_subgraph[i].number_of_nodes())
        density.append(nx.density(frequent_subgraph[i]))
        diamenter.append(nx.diameter(frequent_subgraph[i]))
        support.append(len(suports[i])/47.0)
        labels.extend(list(nx.get_node_attributes(frequent_subgraph[i], "label").values()))
        
    metric['max_degree'] = max_degree
    metric['assortive'] = assortive
    metric['nodes'] = nodes
    metric['density'] = density
    metric['diamenter'] = diamenter
    metric['labels'] = labels
    metric['supports'] = support
    metrics[grupo] = metric
# Out:
# 93
# 335
# 463
# 395

# %%
data = {'cluster': [], 'assortive':[], 'nodes':[],'density':[], 'diamenter':[], 'max_degree':[], 'supports':[], 'total':counts_cls_total }
for item in metrics.items():
    cluster = item[0]
    data['cluster'].append(cluster)
    for metric in item[1].items():
        if (metric[0] != 'labels'):
            data[metric[0]].append(np.mean(metric[1]))
            #print("Cluster: {}; Metric: {}; Mean: {}; STD: {} ".format(cluster, metric[0], np.mean(metric[1]), np.std(metric[1])))

# %%
import pandas as pd
clustere_data = pd.DataFrame(data=data)
clustere_data.sort_values('assortive').round(2)
# Out:
#    cluster  assortive  nodes  density  diamenter  max_degree  supports  total
# 0        0      -0.78    5.0     0.45       2.18        4.41      0.53     22
# 4        4      -0.75    4.0     0.56       2.00        3.27      0.55    128
# 6        6      -0.73    3.0     0.76       1.97        2.34      0.58    261
# 3        3      -0.26    4.0     0.56       2.92        2.55      0.55    323
# 1        1      -0.18    5.0     0.44       3.40        3.18      0.53    320
# 2        2      -0.15    6.0     0.37       3.68        3.89      0.51     38
# 5        5      -0.11    2.0     1.23       1.00        1.45      0.67     88

# %%
data = {'cluster': [], 'assortive':[], 'nodes':[],'density':[], 'diamenter':[], 'max_degree':[], 'supports':[], 'total':counts_cls_total }
for item in metrics.items():
    cluster = item[0]
    data['cluster'].append(cluster)
    for metric in item[1].items():
        if (metric[0] != 'labels'):
            data[metric[0]].append(np.std(metric[1]))
            #print("Cluster: {}; Metric: {}; Mean: {}; STD: {} ".format(cluster, metric[0], np.mean(metric[1]), np.std(metric[1])))

# %%
def keywithmaxval(d):
     """ a) create a list of the dict's keys and values; 
         b) return the key with the max value"""  
     v = list(d.values())
     k = list(d.keys())
     return k[v.index(max(v))]

# %%
central = {}
for i in np.where(hdb.labels_ == 6)[0]:
    g = frequent_subgraph[i]
    labels = nx.get_node_attributes(g, 'label')
    degree = dict(g.degree())
    n = keywithmaxval(degree)
    center = labels[n]
    if not center in central:
        central[center] = set()
    for label in labels:
        if label != n:
            central[center].add(labels[label])
central
# Out:
# {'N': {'C', 'F', 'H', 'I', 'J', 'K', 'L', 'M', 'P', 'Q', 'R', 'S'},
#  'M': {'F', 'G', 'H', 'I', 'J', 'K', 'N', 'P', 'Q', 'R', 'S'},
#  'S': {'C', 'F', 'G', 'H', 'I', 'J', 'K', 'M', 'N', 'Q'},
#  'I': {'H', 'M', 'N'},
#  'G': {'C', 'E', 'F', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S'},
#  'J': {'C', 'G', 'M', 'N', 'P'},
#  'C': {'F', 'G', 'H', 'I', 'J', 'N', 'P', 'S'},
#  'Q': {'C', 'G', 'H', 'M', 'N', 'P', 'S'},
#  'P': {'C', 'G', 'J', 'K', 'M', 'Q', 'R'},
#  'R': {'G', 'P'},
#  'F': {'C', 'G', 'H', 'M', 'N'},
#  'K': {'G', 'H', 'M', 'N', 'P'},
#  'H': {'C', 'F', 'G', 'I', 'K', 'M', 'N', 'Q', 'S'}}

# %%
clustere_data = pd.DataFrame(data=data)
clustere_data.round(2)
# Out:
#    cluster  assortive  nodes  density  diamenter  max_degree  supports  total
# 0        0       0.32    0.0     0.07       0.39        0.94      0.03     22
# 1        1       0.33    0.0     0.05       0.49        0.96      0.02    320
# 2        2       0.33    0.0     0.03       0.65        1.07      0.01     38
# 3        3       0.30    0.0     0.09       0.28        0.82      0.04    323
# 4        4       0.43    0.0     0.09       0.00        0.76      0.04    128
# 5        5       0.21    0.0     0.42       0.00        0.84      0.11     88
# 6        6       0.41    0.0     0.17       0.18        0.66      0.07    261

# %%
for i in set(hdb.labels_.tolist()):
    print(i)
    elements = np.where(hdb.labels_ == i)[0].tolist()
    cluster_ranks = [ l2[j] for j in elements]
    max_index = np.where(np.asarray(cluster_ranks) == max(cluster_ranks))[0].tolist()
    plot_graph(elements[max_index[0]])
# Out:
# 0
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-0.667, -0.333) node[fill=red!20,draw,double,rounded corners] (0){C}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){G}
#         (-0.389, -0.056) node[fill=red!20,draw,double,rounded corners] (2){H}
#         (-0.111, 0.222) node[fill=red!20,draw,double,rounded corners] (3){M}
#         (0.167, 0.5) node[fill=red!20,draw,double,rounded corners] (4){Q};
#       \begin{scope}[-,above]
#         \draw (0) to node[] {High} (1);
#         \draw[loop,] (1) to node[] {High} (1);
#         \draw (1) to node[] {Medium} (2);
#         \draw (1) to node[] {Medium} (3);
#         \draw (1) to node[] {Low} (4);
#       \end{scope}
#     \end{tikzpicture}
# 1
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-0.667, -0.333) node[fill=red!20,draw,double,rounded corners] (0){C}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){G}
# ...

# %%
plot_graph(15)
# Out:
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-0.778, -0.333) node[fill=red!20,draw,double,rounded corners] (0){I}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){M}
#         (-0.333, 0.111) node[fill=red!20,draw,double,rounded corners] (2){J}
#         (0.111, 0.556) node[fill=red!20,draw,double,rounded corners] (3){K};
#       \begin{scope}[-,above]
#         \draw (0) to node[] {Low} (1);
#         \draw (1) to node[] {Low} (2);
#         \draw (1) to node[] {Low} (3);
#       \end{scope}
#     \end{tikzpicture}

# %%
plot_graph(895)
# Out:
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-0.6, -0.333) node[fill=red!20,draw,double,rounded corners] (0){C}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){G}
#         (-0.4, -0.133) node[fill=red!20,draw,double,rounded corners] (2){H}
#         (0.0, 0.267) node[fill=red!20,draw,double,rounded corners] (3){M}
#         (-0.2, 0.067) node[fill=red!20,draw,double,rounded corners] (4){J}
#         (0.2, 0.467) node[fill=red!20,draw,double,rounded corners] (5){Q};
#       \begin{scope}[-,above]
#         \draw (0) to node[] {High} (1);
#         \draw[loop,] (1) to node[] {High} (1);
#         \draw (1) to node[] {Medium} (2);
#         \draw (1) to node[] {Medium} (3);
#         \draw (1) to node[] {Low} (5);
#         \draw (3) to node[] {Low} (4);
#       \end{scope}
#     \end{tikzpicture}

# %%
for item in metrics.items():
    cluster = item[0]
    unique, counts = np.unique(item[1]['labels'], return_counts=True)
    total = dict(zip(unique.tolist(), counts.tolist()))
    print("Cluster: {}".format(cluster))
    print( {k: v for k, v in sorted(total.items(), key=lambda item: item[1])})
    print()
# Out:
# Cluster: 0
# {'I': 2, 'N': 3, 'Q': 6, 'H': 8, 'J': 9, 'S': 9, 'C': 14, 'K': 16, 'G': 21, 'M': 22}
#
# Cluster: 1
# {'R': 2, 'P': 35, 'F': 39, 'I': 46, 'Q': 51, 'S': 79, 'H': 111, 'J': 129, 'N': 133, 'K': 155, 'C': 214, 'G': 303, 'M': 303}
#
# Cluster: 2
# {'I': 4, 'F': 6, 'J': 12, 'S': 14, 'N': 16, 'Q': 16, 'H': 20, 'K': 30, 'C': 34, 'G': 38, 'M': 38}
#
# Cluster: 3
# {'L': 3, 'E': 4, 'R': 5, 'I': 34, 'P': 36, 'Q': 43, 'F': 48, 'S': 69, 'H': 84, 'K': 100, 'J': 110, 'N': 127, 'C': 156, 'M': 221, 'G': 252}
#
# Cluster: 4
# {'L': 4, 'E': 6, 'P': 12, 'F': 16, 'I': 20, 'Q': 24, 'S': 30, 'N': 32, 'J': 42, 'K': 46, 'H': 47, 'C': 54, 'M': 82, 'G': 97}
#
# Cluster: 5
# {'E': 2, 'L': 4, 'J': 6, 'F': 7, 'K': 7, 'I': 9, 'R': 9, 'Q': 12, 'M': 13, 'C': 16, 'H': 16, 'P': 16, 'S': 16, 'N': 20, 'G': 23}
#
# Cluster: 6
# {'E': 10, 'L': 11, 'R': 13, 'I': 27, 'P': 36, 'K': 38, 'F': 39, 'Q': 44, 'S': 51, 'J': 55, 'H': 61, 'N': 79, 'C': 87, 'M': 100, 'G': 132}

# %%
plot_graph(1039)
# Out:
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (0){C}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){G}
#         (0.333, 0.333) node[fill=red!20,draw,double,rounded corners] (2){M}
#         (0.0, 0.0) node[fill=red!20,draw,double,rounded corners] (3){J}
#         (-0.333, 0.333) node[fill=red!20,draw,double,rounded corners] (4){P};
#       \begin{scope}[-,above]
#         \draw (0) to node[] {High} (1);
#         \draw (0) to node[] {Low} (4);
#         \draw[loop,] (1) to node[] {High} (1);
#         \draw (1) to node[] {Medium} (2);
#         \draw (2) to node[] {Low} (3);
#       \end{scope}
#     \end{tikzpicture}

# %%
for i in range(len(frequent_subgraph)):
    try:
        x = nx.find_cycle(frequent_subgraph[i], orientation="ignore")
        if len(x) >= 3:
            plot_graph(i)
    except:
        pass
# Out:
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (0){J}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){M}
#         (0.0, 0.667) node[fill=red!20,draw,double,rounded corners] (2){N};
#       \begin{scope}[-,above]
#         \draw (0) to node[] {Low} (1);
#         \draw (0) to (2);
#         \draw (1) to node[] {Medium} (2);
#       \end{scope}
#     \end{tikzpicture}
#   \begin{tikzpicture}[scale=2.5]
#       \draw
#         (-0.778, -0.333) node[fill=red!20,draw,double,rounded corners] (0){J}
#         (1.0, -0.333) node[fill=red!20,draw,double,rounded corners] (1){M}
#         (-0.333, 0.111) node[fill=red!20,draw,double,rounded corners] (2){K}
#         (0.111, 0.556) node[fill=red!20,draw,double,rounded corners] (3){N};
#       \begin{scope}[-,above]
#         \draw (0) to node[] {Low} (1);
#         \draw (1) to node[] {Low} (2);
#         \draw (1) to (3);
# ...
